# %%
# Make repo root importable for this session (zero packaging)
import sys, pathlib
repo_root = pathlib.Path.cwd().parent if (pathlib.Path.cwd().name == "quickstart") else pathlib.Path.cwd()
sys.path.insert(0, str(repo_root))
# %load_ext autoreload
# %autoreload 2

from datetime import datetime
timestamp = datetime.now().strftime("%y.%m.%d.%H.%M")

dataset_path      = "../data/trumpet1/"      # Path to dataset directory
output_model_path = "output_"+timestamp # Path to save the trained model and configs

# %%
from training.loop import train_model

results = train_model(
    dataset_path      = dataset_path,
    model_output_path = output_model_path,
    num_epochs        = 75,      # Number of epochs. 75 works well for most training sessions.
    batch_size        = 100,    # Number of sequences per batch.
    sequence_length   = 125,    # Number of tokens per training sequence.
    batches_per_epoch = 100,    # Number of batches per epoch.
    learning_rate     = 0.005,  # Adam optimizer learning rate.
    hidden_size       = 128,    # GRU hidden state size.
    num_layers        = 3,      # Number of GRU layers in the model.
    save_interval     = 25,     # Save model every N epochs (last checkpoint is always saved).
    add_noise         = True,   # Whether to add noise to embeddings during training.
    noise_weight      = 0.05,   # Weight of noise added to embeddings during training for stability.
    cascade_mode      = "hard", # Codebook learning mode: "hard" or "soft". If "hard", probabilities are used to sample the codebook token. If "soft", probabilities are used as weights for the loss of each codebook.
    temperature       = 0.8,    # Controls randomness when sampling (only for cascade_mode="hard".)
    top_n             = 8,      # Sample from top_n tokens only (only for cascade_mode="hard".)
    tau_soft          = 0.6,    # Soft cascade temperature (only for cascade_mode="soft".)
    train_splits      = ["train"],      # Training split(s) - None for auto-detect, or "train" or ["train", "extra"].
    # val_splits        = ["validation"], # Validation split(s) - None for auto-detect, or "validation" or ["val1", "val2"].
    TF_schedule       = [4, 4], # Teacher forcing cicle [epochs_on, epochs_off]. Always starts with "on".
    simulate_parallel = False,  # If True, all codebook are learned in parallel (no cascade.)
    use_tensorboard   = True,   # If True, log to TensorBoard.
    use_tqdm          = True,   # If True, show progress bars per epoch.
    val_interval      = 2,      # Run validation every N epochs.
    quantizer_weights = [3.0, 2.0, 1.5, 1.0, 0.8, 0.6, 0.5, 0.4] # Per-codebook loss weights.
)
# Out:
# 🚀 Training Configurations
#
# 💻 Device: cpu
# 📋 Conditioning configuration:
#     Features: pitch
#     Total features: 1
#     FPS: 75
# 📊 Available splits: train
# 📦 Creating data loaders...
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Latents embedded in 64 of the GRU input size of 128
# Conditioning parameters embedded in 64 of the GRU input size of 128
# 🧠 Model created:
#     Device: cpu
#     Conditioning features: 1
#     Hidden size: 128
#     Layers: 3
#     Codebooks: 8
#     Cascade mode: hard
#     Temperature: 0.8
#     Top-k: 8
# 📋 Copied conditioning_config.json to model directory
# saved to /Users/oriolfreixa/Documents/GitHub/GenAI/classnn-OriolFreixa/quickstart/output_26.02.28.18.08/config_v2.pt
# wrote json param file
# 💾 Saved conditioning config to: conditioning_config.pt
# 💾 Output directory: /Users/oriolfreixa/Documents/GitHub/GenAI/classnn-OriolFreixa/quickstart/output_26.02.28.18.08
# 💾 Saved configuration to: /Users/oriolfreixa/Documents/GitHub/GenAI/classnn-OriolFreixa/quickstart/output_26.02.28.18.08/config_v2.pt
#
# 🏋️ Training Started
#
# Epochs: 1 → 75
# Batches per epoch: 100
# Batch size: 100
# TF schedule: [4, 4]
# Simulate parallel: False
# Validation: Disabled
# Tensorboard: Enabled
#     run in a new terminal: tensorboard --logdir=/Users/oriolfreixa/Documents/GitHub/GenAI/classnn-OriolFreixa/quickstart/output_26.02.28.18.08/tensorboard
# ======================================================================
# Epoch   1/75 | TF=ON | Training loss: 22.7406
# Epoch   2/75 | TF=ON | Training loss: 17.4226
# Epoch   3/75 | TF=ON | Training loss: 16.3978
# Epoch   4/75 | TF=ON | Training loss: 15.7825
# Epoch   5/75 | TF=OFF | Training loss: 28.2728
# Epoch   6/75 | TF=OFF | Training loss: 22.3754
# Epoch   7/75 | TF=OFF | Training loss: 20.4092
# Epoch   8/75 | TF=OFF | Training loss: 19.4616
# Epoch   9/75 | TF=ON | Training loss: 13.6649
# Epoch  10/75 | TF=ON | Training loss: 11.3803
# Epoch  11/75 | TF=ON | Training loss: 10.1366
# Epoch  12/75 | TF=ON | Training loss: 9.4320
# Epoch  13/75 | TF=OFF | Training loss: 16.5383
# Epoch  14/75 | TF=OFF | Training loss: 14.1245
# Epoch  15/75 | TF=OFF | Training loss: 13.1121
# Epoch  16/75 | TF=OFF | Training loss: 12.7155
# Epoch  17/75 | TF=ON | Training loss: 9.4206
# Epoch  18/75 | TF=ON | Training loss: 8.0898
# Epoch  19/75 | TF=ON | Training loss: 7.6337
# Epoch  20/75 | TF=ON | Training loss: 7.2123
# Epoch  21/75 | TF=OFF | Training loss: 13.4636
# Epoch  22/75 | TF=OFF | Training loss: 11.9960
# Epoch  23/75 | TF=OFF | Training loss: 11.4153
# Epoch  24/75 | TF=OFF | Training loss: 11.2393
# Epoch  25/75 | TF=ON | Training loss: 8.1753
#    💾 Checkpoint saved at epoch 25
# Epoch  26/75 | TF=ON | Training loss: 7.1322
# Epoch  27/75 | TF=ON | Training loss: 6.6945
# Epoch  28/75 | TF=ON | Training loss: 6.3950
# Epoch  29/75 | TF=OFF | Training loss: 12.5475
# Epoch  30/75 | TF=OFF | Training loss: 11.1079
# Epoch  31/75 | TF=OFF | Training loss: 10.7221
# Epoch  32/75 | TF=OFF | Training loss: 10.5643
# Epoch  33/75 | TF=ON | Training loss: 7.4503
# Epoch  34/75 | TF=ON | Training loss: 6.5562
# Epoch  35/75 | TF=ON | Training loss: 6.2157
# Epoch  36/75 | TF=ON | Training loss: 5.9809
# Epoch  37/75 | TF=OFF | Training loss: 12.0116
# Epoch  38/75 | TF=OFF | Training loss: 10.6664
# Epoch  39/75 | TF=OFF | Training loss: 10.2831
# Epoch  40/75 | TF=OFF | Training loss: 10.6061
# Epoch  41/75 | TF=ON | Training loss: 7.3235
# Epoch  42/75 | TF=ON | Training loss: 6.2616
# Epoch  43/75 | TF=ON | Training loss: 5.9074
# Epoch  44/75 | TF=ON | Training loss: 5.7486
# Epoch  45/75 | TF=OFF | Training loss: 11.7093
# Epoch  46/75 | TF=OFF | Training loss: 10.3656
# Epoch  47/75 | TF=OFF | Training loss: 10.0639
# Epoch  48/75 | TF=OFF | Training loss: 9.8625
# Epoch  49/75 | TF=ON | Training loss: 6.8711
# Epoch  50/75 | TF=ON | Training loss: 6.0110
#    💾 Checkpoint saved at epoch 50
# Epoch  51/75 | TF=ON | Training loss: 5.7303
# Epoch  52/75 | TF=ON | Training loss: 5.5278
# Epoch  53/75 | TF=OFF | Training loss: 11.3510
# Epoch  54/75 | TF=OFF | Training loss: 10.2794
# Epoch  55/75 | TF=OFF | Training loss: 9.7970
# Epoch  56/75 | TF=OFF | Training loss: 9.6755
# Epoch  57/75 | TF=ON | Training loss: 6.6650
# Epoch  58/75 | TF=ON | Training loss: 5.8077
# Epoch  59/75 | TF=ON | Training loss: 5.5521
# Epoch  60/75 | TF=ON | Training loss: 5.3598
# Epoch  61/75 | TF=OFF | Training loss: 11.2607
# Epoch  62/75 | TF=OFF | Training loss: 10.0514
# Epoch  63/75 | TF=OFF | Training loss: 9.7167
# Epoch  64/75 | TF=OFF | Training loss: 9.5500
# Epoch  65/75 | TF=ON | Training loss: 6.5224
# Epoch  66/75 | TF=ON | Training loss: 5.7417
# Epoch  67/75 | TF=ON | Training loss: 5.4278
# Epoch  68/75 | TF=ON | Training loss: 5.2897
# Epoch  69/75 | TF=OFF | Training loss: 11.1195
# Epoch  70/75 | TF=OFF | Training loss: 9.8782
# Epoch  71/75 | TF=OFF | Training loss: 9.5079
# Epoch  72/75 | TF=OFF | Training loss: 9.3518
# Epoch  73/75 | TF=ON | Training loss: 6.3718
# Epoch  74/75 | TF=ON | Training loss: 5.5631
# Epoch  75/75 | TF=ON | Training loss: 5.3010
#    💾 Checkpoint saved at epoch 75
#
# 🏋️ Training Completed
#
# Total time: 03:16:30
# Model saved to: /Users/oriolfreixa/Documents/GitHub/GenAI/classnn-OriolFreixa/quickstart/output_26.02.28.18.08
# ======================================================================
