# %%
# Make repo root importable for this session (zero packaging)
import sys, pathlib
repo_root = pathlib.Path.cwd().parent if (pathlib.Path.cwd().name == "quickstart") else pathlib.Path.cwd()
sys.path.insert(0, str(repo_root))
# %load_ext autoreload
# %autoreload 2

from datetime import datetime
timestamp = datetime.now().strftime("%y.%m.%d.%H.%M")

dataset_path      = "../data/trumpet-class/"      # Path to dataset directory
output_model_path = "output_class_"+timestamp # Path to save the trained model and configs

# %%
from training.loop import train_model

results = train_model(
    dataset_path      = dataset_path,
    model_output_path = output_model_path,
    num_epochs        = 75,      # Number of epochs. 75 works well for most training sessions.
    batch_size        = 100,    # Number of sequences per batch.
    sequence_length   = 125,    # Number of tokens per training sequence.
    batches_per_epoch = 100,    # Number of batches per epoch.
    learning_rate     = 0.005,  # Adam optimizer learning rate.
    hidden_size       = 128,    # GRU hidden state size.
    num_layers        = 3,      # Number of GRU layers in the model.
    save_interval     = 25,     # Save model every N epochs (last checkpoint is always saved).
    add_noise         = True,   # Whether to add noise to embeddings during training.
    noise_weight      = 0.05,   # Weight of noise added to embeddings during training for stability.
    cascade_mode      = "hard", # Codebook learning mode: "hard" or "soft". If "hard", probabilities are used to sample the codebook token. If "soft", probabilities are used as weights for the loss of each codebook.
    temperature       = 0.8,    # Controls randomness when sampling (only for cascade_mode="hard".)
    top_n             = 8,      # Sample from top_n tokens only (only for cascade_mode="hard".)
    tau_soft          = 0.6,    # Soft cascade temperature (only for cascade_mode="soft".)
    train_splits      = ["train"],      # Training split(s) - None for auto-detect, or "train" or ["train", "extra"].
    # val_splits        = ["validation"], # Validation split(s) - None for auto-detect, or "validation" or ["val1", "val2"].
    TF_schedule       = [4, 4], # Teacher forcing cicle [epochs_on, epochs_off]. Always starts with "on".
    simulate_parallel = False,  # If True, all codebook are learned in parallel (no cascade.)
    use_tensorboard   = True,   # If True, log to TensorBoard.
    use_tqdm          = True,   # If True, show progress bars per epoch.
    val_interval      = 2,      # Run validation every N epochs.
    quantizer_weights = [3.0, 2.0, 1.5, 1.0, 0.8, 0.6, 0.5, 0.4] # Per-codebook loss weights.
)
# Out:
# 🚀 Training Configurations
#
# 💻 Device: cpu
# 📋 Conditioning configuration:
#     Features: class_C, class_C#, class_D, class_D#, class_E, class_F, class_F#, class_G, class_G#, class_A, class_A#, class_B
#     Total features: 12
#     FPS: 75
# 📊 Available splits: train
# 📦 Creating data loaders...
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Latents embedded in 64 of the GRU input size of 128
# Conditioning parameters embedded in 64 of the GRU input size of 128
# 🧠 Model created:
#     Device: cpu
#     Conditioning features: 12
#     Hidden size: 128
#     Layers: 3
#     Codebooks: 8
#     Cascade mode: hard
#     Temperature: 0.8
#     Top-k: 8
# 📋 Copied conditioning_config.json to model directory
# saved to /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_class_26.03.12.11.16/config_v2.pt
# wrote json param file
# 💾 Saved conditioning config to: conditioning_config.pt
# 💾 Output directory: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_class_26.03.12.11.16
# 💾 Saved configuration to: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_class_26.03.12.11.16/config_v2.pt
#
# 🏋️ Training Started
#
# Epochs: 1 → 75
# Batches per epoch: 100
# Batch size: 100
# TF schedule: [4, 4]
# Simulate parallel: False
# Validation: Disabled
# Tensorboard: Enabled
#     run in a new terminal: tensorboard --logdir=/Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_class_26.03.12.11.16/tensorboard
# ======================================================================
# Epoch   1/75 | TF=ON | Training loss: 23.2094
# Epoch   2/75 | TF=ON | Training loss: 17.4935
# Epoch   3/75 | TF=ON | Training loss: 16.4479
# Epoch   4/75 | TF=ON | Training loss: 15.5400
# Epoch   5/75 | TF=OFF | Training loss: 27.1889
# Epoch   6/75 | TF=OFF | Training loss: 23.5266
# Epoch   7/75 | TF=OFF | Training loss: 22.6501
# Epoch   8/75 | TF=OFF | Training loss: 21.0164
# Epoch   9/75 | TF=ON | Training loss: 14.4764
# Epoch  10/75 | TF=ON | Training loss: 12.2105
# Epoch  11/75 | TF=ON | Training loss: 11.1326
# Epoch  12/75 | TF=ON | Training loss: 10.2660
# Epoch  13/75 | TF=OFF | Training loss: 17.7626
# Epoch  14/75 | TF=OFF | Training loss: 14.7273
# Epoch  15/75 | TF=OFF | Training loss: 13.5729
# Epoch  16/75 | TF=OFF | Training loss: 12.6765
# Epoch  17/75 | TF=ON | Training loss: 9.4310
# Epoch  18/75 | TF=ON | Training loss: 8.1489
# Epoch  19/75 | TF=ON | Training loss: 7.5092
# Epoch  20/75 | TF=ON | Training loss: 7.1263
# Epoch  21/75 | TF=OFF | Training loss: 13.2798
# Epoch  22/75 | TF=OFF | Training loss: 11.5711
# Epoch  23/75 | TF=OFF | Training loss: 11.1391
# Epoch  24/75 | TF=OFF | Training loss: 10.8964
# Epoch  25/75 | TF=ON | Training loss: 7.8792
#    💾 Checkpoint saved at epoch 25
# Epoch  26/75 | TF=ON | Training loss: 6.8407
# Epoch  27/75 | TF=ON | Training loss: 6.4452
# Epoch  28/75 | TF=ON | Training loss: 6.1503
# Epoch  29/75 | TF=OFF | Training loss: 12.0814
# Epoch  30/75 | TF=OFF | Training loss: 10.7095
# Epoch  31/75 | TF=OFF | Training loss: 10.3746
# Epoch  32/75 | TF=OFF | Training loss: 10.1200
# Epoch  33/75 | TF=ON | Training loss: 7.1309
# Epoch  34/75 | TF=ON | Training loss: 6.2606
# Epoch  35/75 | TF=ON | Training loss: 5.9259
# Epoch  36/75 | TF=ON | Training loss: 5.6937
# Epoch  37/75 | TF=OFF | Training loss: 11.4998
# Epoch  38/75 | TF=OFF | Training loss: 10.2005
# Epoch  39/75 | TF=OFF | Training loss: 9.8733
# Epoch  40/75 | TF=OFF | Training loss: 9.7023
# Epoch  41/75 | TF=ON | Training loss: 6.7871
# Epoch  42/75 | TF=ON | Training loss: 5.9165
# Epoch  43/75 | TF=ON | Training loss: 5.6266
# Epoch  44/75 | TF=ON | Training loss: 5.4366
# Epoch  45/75 | TF=OFF | Training loss: 11.0989
# Epoch  46/75 | TF=OFF | Training loss: 9.9008
# Epoch  47/75 | TF=OFF | Training loss: 9.5342
# Epoch  48/75 | TF=OFF | Training loss: 9.4000
# Epoch  49/75 | TF=ON | Training loss: 6.5082
# Epoch  50/75 | TF=ON | Training loss: 5.6644
#    💾 Checkpoint saved at epoch 50
# Epoch  51/75 | TF=ON | Training loss: 5.4150
# Epoch  52/75 | TF=ON | Training loss: 5.2256
# Epoch  53/75 | TF=OFF | Training loss: 10.8311
# Epoch  54/75 | TF=OFF | Training loss: 9.7464
# Epoch  55/75 | TF=OFF | Training loss: 9.3946
# Epoch  56/75 | TF=OFF | Training loss: 9.2430
# Epoch  57/75 | TF=ON | Training loss: 6.3105
# Epoch  58/75 | TF=ON | Training loss: 5.5216
# Epoch  59/75 | TF=ON | Training loss: 5.2189
# Epoch  60/75 | TF=ON | Training loss: 5.0701
# Epoch  61/75 | TF=OFF | Training loss: 10.6467
# Epoch  62/75 | TF=OFF | Training loss: 9.5705
# Epoch  63/75 | TF=OFF | Training loss: 9.3048
# Epoch  64/75 | TF=OFF | Training loss: 9.0785
# Epoch  65/75 | TF=ON | Training loss: 6.1535
# Epoch  66/75 | TF=ON | Training loss: 5.3843
# Epoch  67/75 | TF=ON | Training loss: 5.0739
# Epoch  68/75 | TF=ON | Training loss: 4.9757
# Epoch  69/75 | TF=OFF | Training loss: 10.5923
# Epoch  70/75 | TF=OFF | Training loss: 9.4048
# Epoch  71/75 | TF=OFF | Training loss: 9.0951
# Epoch  72/75 | TF=OFF | Training loss: 8.9104
# Epoch  73/75 | TF=ON | Training loss: 6.0539
# Epoch  74/75 | TF=ON | Training loss: 5.3025
# Epoch  75/75 | TF=ON | Training loss: 5.0660
#    💾 Checkpoint saved at epoch 75
#
# 🏋️ Training Completed
#
# Total time: 06:25:01
# Model saved to: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_class_26.03.12.11.16
# ======================================================================

# %%
from training.loop import train_model

dataset_path      = "../data/trumpet1/"      # Path to dataset directory
output_model_path = "output_Film_"+timestamp # Path to save the trained model and configs
results = train_model(
    dataset_path      = dataset_path,
    model_output_path = output_model_path,
    num_epochs        = 75,      # Number of epochs. 75 works well for most training sessions.
    batch_size        = 100,    # Number of sequences per batch.
    sequence_length   = 125,    # Number of tokens per training sequence.
    batches_per_epoch = 100,    # Number of batches per epoch.
    learning_rate     = 0.005,  # Adam optimizer learning rate.
    hidden_size       = 128,    # GRU hidden state size.
    num_layers        = 3,      # Number of GRU layers in the model.
    save_interval     = 25,     # Save model every N epochs (last checkpoint is always saved).
    add_noise         = True,   # Whether to add noise to embeddings during training.
    noise_weight      = 0.05,   # Weight of noise added to embeddings during training for stability.
    cascade_mode      = "hard", # Codebook learning mode: "hard" or "soft". If "hard", probabilities are used to sample the codebook token. If "soft", probabilities are used as weights for the loss of each codebook.
    conditioning_mode= "film", # Input conditioning path ("concat", "film")
    temperature       = 0.8,    # Controls randomness when sampling (only for cascade_mode="hard".)
    top_n             = 8,      # Sample from top_n tokens only (only for cascade_mode="hard".)
    tau_soft          = 0.6,    # Soft cascade temperature (only for cascade_mode="soft".)
    train_splits      = ["train"],      # Training split(s) - None for auto-detect, or "train" or ["train", "extra"].
    # val_splits        = ["validation"], # Validation split(s) - None for auto-detect, or "validation" or ["val1", "val2"].
    TF_schedule       = [4, 4], # Teacher forcing cicle [epochs_on, epochs_off]. Always starts with "on".
    simulate_parallel = False,  # If True, all codebook are learned in parallel (no cascade.)
    use_tensorboard   = True,   # If True, log to TensorBoard.
    use_tqdm          = True,   # If True, show progress bars per epoch.
    val_interval      = 2,      # Run validation every N epochs.
    quantizer_weights = [3.0, 2.0, 1.5, 1.0, 0.8, 0.6, 0.5, 0.4] # Per-codebook loss weights.
)
# Out:
# 🚀 Training Configurations
#
# 💻 Device: cpu
# 📋 Conditioning configuration:
#     Features: pitch
#     Total features: 1
#     FPS: 75
# 📊 Available splits: train
# 📦 Creating data loaders...
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Latents embedded in 128 of the GRU input size of 128
# FiLM conditioning enabled on GRU input
# 🧠 Model created:
#     Device: cpu
#     Conditioning features: 1
#     Hidden size: 128
#     Layers: 3
#     Codebooks: 8
#     Conditioning mode: film
#     Cascade mode: hard
#     Temperature: 0.8
#     Top-k: 8
# 📋 Copied conditioning_config.json to model directory
# saved to /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_Film_26.03.12.11.16/config_v2.pt
# wrote json param file
# 💾 Saved conditioning config to: conditioning_config.pt
# 💾 Output directory: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_Film_26.03.12.11.16
# 💾 Saved configuration to: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_Film_26.03.12.11.16/config_v2.pt
#
# 🏋️ Training Started
#
# Epochs: 1 → 75
# Batches per epoch: 100
# Batch size: 100
# TF schedule: [4, 4]
# Simulate parallel: False
# Validation: Disabled
# Tensorboard: Enabled
#     run in a new terminal: tensorboard --logdir=/Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_Film_26.03.12.11.16/tensorboard
# ======================================================================
# Epoch   1/75 | TF=ON | Training loss: 23.3170
# Epoch   2/75 | TF=ON | Training loss: 17.4542
# Epoch   3/75 | TF=ON | Training loss: 16.3756
# Epoch   4/75 | TF=ON | Training loss: 15.8773
# Epoch   5/75 | TF=OFF | Training loss: 29.0419
# Epoch   6/75 | TF=OFF | Training loss: 22.5798
# Epoch   7/75 | TF=OFF | Training loss: 20.5029
# Epoch   8/75 | TF=OFF | Training loss: 19.4128
# Epoch   9/75 | TF=ON | Training loss: 14.5013
# Epoch  10/75 | TF=ON | Training loss: 12.7171
# Epoch  11/75 | TF=ON | Training loss: 11.9006
# Epoch  12/75 | TF=ON | Training loss: 11.2598
# Epoch  13/75 | TF=OFF | Training loss: 20.5640
# Epoch  14/75 | TF=OFF | Training loss: 17.7588
# Epoch  15/75 | TF=OFF | Training loss: 16.4746
# Epoch  16/75 | TF=OFF | Training loss: 15.7247
# Epoch  17/75 | TF=ON | Training loss: 11.6925
# Epoch  18/75 | TF=ON | Training loss: 10.0898
# Epoch  19/75 | TF=ON | Training loss: 9.5275
# Epoch  20/75 | TF=ON | Training loss: 9.0194
# Epoch  21/75 | TF=OFF | Training loss: 16.4792
# Epoch  22/75 | TF=OFF | Training loss: 14.3981
# Epoch  23/75 | TF=OFF | Training loss: 13.9080
# Epoch  24/75 | TF=OFF | Training loss: 13.4668
# Epoch  25/75 | TF=ON | Training loss: 9.9126
#    💾 Checkpoint saved at epoch 25
# Epoch  26/75 | TF=ON | Training loss: 8.7763
# Epoch  27/75 | TF=ON | Training loss: 8.3253
# Epoch  28/75 | TF=ON | Training loss: 8.0201
# Epoch  29/75 | TF=OFF | Training loss: 14.8509
# Epoch  30/75 | TF=OFF | Training loss: 13.2648
# Epoch  31/75 | TF=OFF | Training loss: 12.7296
# Epoch  32/75 | TF=OFF | Training loss: 12.4606
# Epoch  33/75 | TF=ON | Training loss: 9.2093
# Epoch  34/75 | TF=ON | Training loss: 8.0772
# Epoch  35/75 | TF=ON | Training loss: 7.6989
# Epoch  36/75 | TF=ON | Training loss: 7.4733
# Epoch  37/75 | TF=OFF | Training loss: 14.0707
# Epoch  38/75 | TF=OFF | Training loss: 12.5833
# Epoch  39/75 | TF=OFF | Training loss: 12.1749
# Epoch  40/75 | TF=OFF | Training loss: 11.9813
# Epoch  41/75 | TF=ON | Training loss: 8.6570
# Epoch  42/75 | TF=ON | Training loss: 7.6303
# Epoch  43/75 | TF=ON | Training loss: 7.2537
# Epoch  44/75 | TF=ON | Training loss: 6.9861
# Epoch  45/75 | TF=OFF | Training loss: 13.5830
# Epoch  46/75 | TF=OFF | Training loss: 12.1412
# Epoch  47/75 | TF=OFF | Training loss: 11.6384
# Epoch  48/75 | TF=OFF | Training loss: 11.5362
# Epoch  49/75 | TF=ON | Training loss: 8.2194
# Epoch  50/75 | TF=ON | Training loss: 7.2847
#    💾 Checkpoint saved at epoch 50
# Epoch  51/75 | TF=ON | Training loss: 6.8887
# Epoch  52/75 | TF=ON | Training loss: 6.6673
# Epoch  53/75 | TF=OFF | Training loss: 13.1224
# Epoch  54/75 | TF=OFF | Training loss: 11.7224
# Epoch  55/75 | TF=OFF | Training loss: 11.3968
# Epoch  56/75 | TF=OFF | Training loss: 11.2580
# Epoch  57/75 | TF=ON | Training loss: 7.9264
# Epoch  58/75 | TF=ON | Training loss: 8.4096
# Epoch  59/75 | TF=ON | Training loss: 6.7407
# Epoch  60/75 | TF=ON | Training loss: 6.5420
# Epoch  61/75 | TF=OFF | Training loss: 12.9681
# Epoch  62/75 | TF=OFF | Training loss: 11.5017
# Epoch  63/75 | TF=OFF | Training loss: 11.1929
# Epoch  64/75 | TF=OFF | Training loss: 10.9916
# Epoch  65/75 | TF=ON | Training loss: 7.6888
# Epoch  66/75 | TF=ON | Training loss: 6.8001
# Epoch  67/75 | TF=ON | Training loss: 6.4776
# Epoch  68/75 | TF=ON | Training loss: 6.2751
# Epoch  69/75 | TF=OFF | Training loss: 12.7009
# Epoch  70/75 | TF=OFF | Training loss: 11.1370
# Epoch  71/75 | TF=OFF | Training loss: 10.9236
# Epoch  72/75 | TF=OFF | Training loss: 10.9085
# Epoch  73/75 | TF=ON | Training loss: 7.5573
# Epoch  74/75 | TF=ON | Training loss: 6.5953
# Epoch  75/75 | TF=ON | Training loss: 6.3417
#    💾 Checkpoint saved at epoch 75
#
# 🏋️ Training Completed
#
# Total time: 03:35:14
# Model saved to: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_Film_26.03.12.11.16
# ======================================================================
