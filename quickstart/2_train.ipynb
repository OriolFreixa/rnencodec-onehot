# %%
# Make repo root importable for this session (zero packaging)
import sys, pathlib
repo_root = pathlib.Path.cwd().parent if (pathlib.Path.cwd().name == "quickstart") else pathlib.Path.cwd()
sys.path.insert(0, str(repo_root))
# %load_ext autoreload
# %autoreload 2

from datetime import datetime
timestamp = datetime.now().strftime("%y.%m.%d.%H.%M")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from training.loop import train_model

dataset_path      = "../data/trumpet1/"      # Path to dataset directory
output_model_path = "output_"+timestamp # Path to save the trained model and configs
results = train_model(
    dataset_path      = dataset_path,
    model_output_path = output_model_path,
    num_epochs        = 75,      # Number of epochs. 75 works well for most training sessions.
    batch_size        = 100,    # Number of sequences per batch.
    sequence_length   = 125,    # Number of tokens per training sequence.
    batches_per_epoch = 100,    # Number of batches per epoch.
    learning_rate     = 0.005,  # Adam optimizer learning rate.
    hidden_size       = 128,    # GRU hidden state size.
    num_layers        = 3,      # Number of GRU layers in the model.
    save_interval     = 25,     # Save model every N epochs (last checkpoint is always saved).
    add_noise         = True,   # Whether to add noise to embeddings during training.
    noise_weight      = 0.05,   # Weight of noise added to embeddings during training for stability.
    cascade_mode      = "hard", # Codebook learning mode: "hard" or "soft". If "hard", probabilities are used to sample the codebook token. If "soft", probabilities are used as weights for the loss of each codebook.
    temperature       = 0.8,    # Controls randomness when sampling (only for cascade_mode="hard".)
    top_n             = 8,      # Sample from top_n tokens only (only for cascade_mode="hard".)
    tau_soft          = 0.6,    # Soft cascade temperature (only for cascade_mode="soft".)
    train_splits      = ["train"],      # Training split(s) - None for auto-detect, or "train" or ["train", "extra"].
    # val_splits        = ["validation"], # Validation split(s) - None for auto-detect, or "validation" or ["val1", "val2"].
    TF_schedule       = [4, 4], # Teacher forcing cicle [epochs_on, epochs_off]. Always starts with "on".
    simulate_parallel = False,  # If True, all codebook are learned in parallel (no cascade.)
    use_tensorboard   = True,   # If True, log to TensorBoard.
    use_tqdm          = True,   # If True, show progress bars per epoch.
    val_interval      = 2,      # Run validation every N epochs.
    quantizer_weights = [3.0, 2.0, 1.5, 1.0, 0.8, 0.6, 0.5, 0.4] # Per-codebook loss weights.
)
# Out:
# 🚀 Training Configurations
#
# 💻 Device: cpu
# 📋 Conditioning configuration:
#     Features: pitch
#     Total features: 1
#     FPS: 75
# 📊 Available splits: train
# 📦 Creating data loaders...
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Latents embedded in 64 of the GRU input size of 128
# Conditioning parameters embedded in 64 of the GRU input size of 128
# 🧠 Model created:
#     Device: cpu
#     Conditioning features: 1
#     Hidden size: 128
#     Layers: 3
#     Codebooks: 8
#     Conditioning mode: concat
#     Cascade mode: hard
#     Temperature: 0.8
#     Top-k: 8
# 📋 Copied conditioning_config.json to model directory
# saved to /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_26.03.19.18.38/config_v2.pt
# wrote json param file
# 💾 Saved conditioning config to: conditioning_config.pt
# 💾 Output directory: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_26.03.19.18.38
# 💾 Saved configuration to: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_26.03.19.18.38/config_v2.pt
#
# 🏋️ Training Started
#
# Epochs: 1 → 75
# Batches per epoch: 100
# Batch size: 100
# TF schedule: [4, 4]
# Simulate parallel: False
# Validation: Disabled
# Tensorboard: Enabled
#     run in a new terminal: tensorboard --logdir=/Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_26.03.19.18.38/tensorboard
# ======================================================================
# Epoch   1/75 | TF=ON | Training loss: 34.2716
# Epoch   2/75 | TF=ON | Training loss: 25.2424
# Epoch   3/75 | TF=ON | Training loss: 22.2998
# Epoch   4/75 | TF=ON | Training loss: 20.4244
# Epoch   5/75 | TF=OFF | Training loss: 35.5654
# Epoch   6/75 | TF=OFF | Training loss: 28.7332
# Epoch   7/75 | TF=OFF | Training loss: 28.3158
# Epoch   8/75 | TF=OFF | Training loss: 24.9908
# Epoch   9/75 | TF=ON | Training loss: 18.1384
# Epoch  10/75 | TF=ON | Training loss: 15.0355
# Epoch  11/75 | TF=ON | Training loss: 13.7200
# Epoch  12/75 | TF=ON | Training loss: 12.8267
# Epoch  13/75 | TF=OFF | Training loss: 23.3750
# Epoch  14/75 | TF=OFF | Training loss: 20.2410
# Epoch  15/75 | TF=OFF | Training loss: 19.2740
# Epoch  16/75 | TF=OFF | Training loss: 18.7839
# Epoch  17/75 | TF=ON | Training loss: 13.6794
# Epoch  18/75 | TF=ON | Training loss: 11.7865
# Epoch  19/75 | TF=ON | Training loss: 11.0875
# Epoch  20/75 | TF=ON | Training loss: 10.6075
# Epoch  21/75 | TF=OFF | Training loss: 20.7075
# Epoch  22/75 | TF=OFF | Training loss: 18.1823
# Epoch  23/75 | TF=OFF | Training loss: 17.5047
# Epoch  24/75 | TF=OFF | Training loss: 17.1735
# Epoch  25/75 | TF=ON | Training loss: 12.1953
#    💾 Checkpoint saved at epoch 25
# Epoch  26/75 | TF=ON | Training loss: 10.5400
# Epoch  27/75 | TF=ON | Training loss: 9.9595
# Epoch  28/75 | TF=ON | Training loss: 9.5827
# Epoch  29/75 | TF=OFF | Training loss: 19.5090
# Epoch  30/75 | TF=OFF | Training loss: 17.1513
# Epoch  31/75 | TF=OFF | Training loss: 16.5555
# Epoch  32/75 | TF=OFF | Training loss: 16.2630
# Epoch  33/75 | TF=ON | Training loss: 11.3512
# Epoch  34/75 | TF=ON | Training loss: 9.8379
# Epoch  35/75 | TF=ON | Training loss: 9.3248
# Epoch  36/75 | TF=ON | Training loss: 9.0073
# Epoch  37/75 | TF=OFF | Training loss: 18.6980
# Epoch  38/75 | TF=OFF | Training loss: 16.5348
# Epoch  39/75 | TF=OFF | Training loss: 15.9987
# Epoch  40/75 | TF=OFF | Training loss: 15.7099
# Epoch  41/75 | TF=ON | Training loss: 10.8055
# Epoch  42/75 | TF=ON | Training loss: 9.3887
# Epoch  43/75 | TF=ON | Training loss: 8.8955
# Epoch  44/75 | TF=ON | Training loss: 8.6212
# Epoch  45/75 | TF=OFF | Training loss: 18.2383
# Epoch  46/75 | TF=OFF | Training loss: 16.0779
# Epoch  47/75 | TF=OFF | Training loss: 15.5714
# Epoch  48/75 | TF=OFF | Training loss: 15.3141
# Epoch  49/75 | TF=ON | Training loss: 10.4288
# Epoch  50/75 | TF=ON | Training loss: 9.0650
#    💾 Checkpoint saved at epoch 50
# Epoch  51/75 | TF=ON | Training loss: 8.6181
# Epoch  52/75 | TF=ON | Training loss: 8.3472
# Epoch  53/75 | TF=OFF | Training loss: 17.7919
# Epoch  54/75 | TF=OFF | Training loss: 15.7252
# Epoch  55/75 | TF=OFF | Training loss: 15.2719
# Epoch  56/75 | TF=OFF | Training loss: 15.0068
# Epoch  57/75 | TF=ON | Training loss: 10.1313
# Epoch  58/75 | TF=ON | Training loss: 8.8354
# Epoch  59/75 | TF=ON | Training loss: 8.3971
# Epoch  60/75 | TF=ON | Training loss: 8.1394
# Epoch  61/75 | TF=OFF | Training loss: 17.5166
# Epoch  62/75 | TF=OFF | Training loss: 15.5102
# Epoch  63/75 | TF=OFF | Training loss: 14.9911
# Epoch  64/75 | TF=OFF | Training loss: 14.7678
# Epoch  65/75 | TF=ON | Training loss: 9.9126
# Epoch  66/75 | TF=ON | Training loss: 8.6459
# Epoch  67/75 | TF=ON | Training loss: 8.2052
# Epoch  68/75 | TF=ON | Training loss: 7.9709
# Epoch  69/75 | TF=OFF | Training loss: 17.1808
# Epoch  70/75 | TF=OFF | Training loss: 15.2648
# Epoch  71/75 | TF=OFF | Training loss: 14.8287
# Epoch  72/75 | TF=OFF | Training loss: 14.5779
# Epoch  73/75 | TF=ON | Training loss: 9.7363
# Epoch  74/75 | TF=ON | Training loss: 8.4821
# Epoch  75/75 | TF=ON | Training loss: 8.0798
#    💾 Checkpoint saved at epoch 75
#
# 🏋️ Training Completed
#
# Total time: 03:04:43
# Model saved to: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_26.03.19.18.38
# ======================================================================

# %%
from training.loop import train_model
dataset_path      = "../data/trumpet-class/"      # Path to dataset directory
output_model_path = "output_class_"+timestamp # Path to save the trained model and configs
results = train_model(
    dataset_path      = dataset_path,
    model_output_path = output_model_path,
    num_epochs        = 75,      # Number of epochs. 75 works well for most training sessions.
    batch_size        = 100,    # Number of sequences per batch.
    sequence_length   = 125,    # Number of tokens per training sequence.
    batches_per_epoch = 100,    # Number of batches per epoch.
    learning_rate     = 0.005,  # Adam optimizer learning rate.
    hidden_size       = 128,    # GRU hidden state size.
    num_layers        = 3,      # Number of GRU layers in the model.
    save_interval     = 25,     # Save model every N epochs (last checkpoint is always saved).
    add_noise         = True,   # Whether to add noise to embeddings during training.
    noise_weight      = 0.05,   # Weight of noise added to embeddings during training for stability.
    cascade_mode      = "hard", # Codebook learning mode: "hard" or "soft". If "hard", probabilities are used to sample the codebook token. If "soft", probabilities are used as weights for the loss of each codebook.
    temperature       = 0.8,    # Controls randomness when sampling (only for cascade_mode="hard".)
    top_n             = 8,      # Sample from top_n tokens only (only for cascade_mode="hard".)
    tau_soft          = 0.6,    # Soft cascade temperature (only for cascade_mode="soft".)
    train_splits      = ["train"],      # Training split(s) - None for auto-detect, or "train" or ["train", "extra"].
    # val_splits        = ["validation"], # Validation split(s) - None for auto-detect, or "validation" or ["val1", "val2"].
    TF_schedule       = [4, 4], # Teacher forcing cicle [epochs_on, epochs_off]. Always starts with "on".
    simulate_parallel = False,  # If True, all codebook are learned in parallel (no cascade.)
    use_tensorboard   = True,   # If True, log to TensorBoard.
    use_tqdm          = True,   # If True, show progress bars per epoch.
    val_interval      = 2,      # Run validation every N epochs.
    quantizer_weights = [3.0, 2.0, 1.5, 1.0, 0.8, 0.6, 0.5, 0.4] # Per-codebook loss weights.
)
# Out:
# 🚀 Training Configurations
#
# 💻 Device: cpu
# 📋 Conditioning configuration:
#     Features: class_C, class_C#, class_D, class_D#, class_E, class_F, class_F#, class_G, class_G#, class_A, class_A#, class_B
#     Total features: 12
#     FPS: 75
# 📊 Available splits: train
# 📦 Creating data loaders...
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Latents embedded in 64 of the GRU input size of 128
# Conditioning parameters embedded in 64 of the GRU input size of 128
# 🧠 Model created:
#     Device: cpu
#     Conditioning features: 12
#     Hidden size: 128
#     Layers: 3
#     Codebooks: 8
#     Conditioning mode: concat
#     Cascade mode: hard
#     Temperature: 0.8
#     Top-k: 8
# 📋 Copied conditioning_config.json to model directory
# saved to /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_class_26.03.19.18.38/config_v2.pt
# wrote json param file
# 💾 Saved conditioning config to: conditioning_config.pt
# 💾 Output directory: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_class_26.03.19.18.38
# 💾 Saved configuration to: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_class_26.03.19.18.38/config_v2.pt
#
# 🏋️ Training Started
#
# Epochs: 1 → 75
# Batches per epoch: 100
# Batch size: 100
# TF schedule: [4, 4]
# Simulate parallel: False
# Validation: Disabled
# Tensorboard: Enabled
#     run in a new terminal: tensorboard --logdir=/Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_class_26.03.19.18.38/tensorboard
# ======================================================================
# Epoch   1/75 | TF=ON | Training loss: 32.6534
# Epoch   2/75 | TF=ON | Training loss: 22.8323
# Epoch   3/75 | TF=ON | Training loss: 20.2816
# Epoch   4/75 | TF=ON | Training loss: 18.5164
# Epoch   5/75 | TF=OFF | Training loss: 31.0710
# Epoch   6/75 | TF=OFF | Training loss: 25.1723
# Epoch   7/75 | TF=OFF | Training loss: 22.8931
# Epoch   8/75 | TF=OFF | Training loss: 21.4611
# Epoch   9/75 | TF=ON | Training loss: 15.9309
# Epoch  10/75 | TF=ON | Training loss: 13.3908
# Epoch  11/75 | TF=ON | Training loss: 12.2874
# Epoch  12/75 | TF=ON | Training loss: 11.5401
# Epoch  13/75 | TF=OFF | Training loss: 21.3737
# Epoch  14/75 | TF=OFF | Training loss: 18.6346
# Epoch  15/75 | TF=OFF | Training loss: 17.8276
# Epoch  16/75 | TF=OFF | Training loss: 17.3314
# Epoch  17/75 | TF=ON | Training loss: 12.5063
# Epoch  18/75 | TF=ON | Training loss: 10.7909
# Epoch  19/75 | TF=ON | Training loss: 10.1287
# Epoch  20/75 | TF=ON | Training loss: 9.6770
# Epoch  21/75 | TF=OFF | Training loss: 19.1395
# Epoch  22/75 | TF=OFF | Training loss: 16.8749
# Epoch  23/75 | TF=OFF | Training loss: 16.2962
# Epoch  24/75 | TF=OFF | Training loss: 15.9236
# Epoch  25/75 | TF=ON | Training loss: 11.1666
#    💾 Checkpoint saved at epoch 25
# Epoch  26/75 | TF=ON | Training loss: 9.7057
# Epoch  27/75 | TF=ON | Training loss: 9.1838
# Epoch  28/75 | TF=ON | Training loss: 8.8399
# Epoch  29/75 | TF=OFF | Training loss: 18.0506
# Epoch  30/75 | TF=OFF | Training loss: 16.0546
# Epoch  31/75 | TF=OFF | Training loss: 15.4525
# Epoch  32/75 | TF=OFF | Training loss: 15.1888
# Epoch  33/75 | TF=ON | Training loss: 10.4629
# Epoch  34/75 | TF=ON | Training loss: 9.0847
# Epoch  35/75 | TF=ON | Training loss: 8.6274
# Epoch  36/75 | TF=ON | Training loss: 8.3345
# Epoch  37/75 | TF=OFF | Training loss: 17.3738
# Epoch  38/75 | TF=OFF | Training loss: 15.4585
# Epoch  39/75 | TF=OFF | Training loss: 14.9283
# Epoch  40/75 | TF=OFF | Training loss: 14.7033
# Epoch  41/75 | TF=ON | Training loss: 9.9754
# Epoch  42/75 | TF=ON | Training loss: 8.7288
# Epoch  43/75 | TF=ON | Training loss: 8.2892
# Epoch  44/75 | TF=ON | Training loss: 7.9937
# Epoch  45/75 | TF=OFF | Training loss: 16.9271
# Epoch  46/75 | TF=OFF | Training loss: 15.0472
# Epoch  47/75 | TF=OFF | Training loss: 14.5607
# Epoch  48/75 | TF=OFF | Training loss: 14.3309
# Epoch  49/75 | TF=ON | Training loss: 9.6449
# Epoch  50/75 | TF=ON | Training loss: 8.4150
#    💾 Checkpoint saved at epoch 50
# Epoch  51/75 | TF=ON | Training loss: 8.0021
# Epoch  52/75 | TF=ON | Training loss: 7.7580
# Epoch  53/75 | TF=OFF | Training loss: 16.5523
# Epoch  54/75 | TF=OFF | Training loss: 14.7634
# Epoch  55/75 | TF=OFF | Training loss: 14.2830
# Epoch  56/75 | TF=OFF | Training loss: 14.0724
# Epoch  57/75 | TF=ON | Training loss: 9.3895
# Epoch  58/75 | TF=ON | Training loss: 8.1977
# Epoch  59/75 | TF=ON | Training loss: 7.8068
# Epoch  60/75 | TF=ON | Training loss: 7.5762
# Epoch  61/75 | TF=OFF | Training loss: 16.2415
# Epoch  62/75 | TF=OFF | Training loss: 14.5132
# Epoch  63/75 | TF=OFF | Training loss: 14.0572
# Epoch  64/75 | TF=OFF | Training loss: 13.8601
# Epoch  65/75 | TF=ON | Training loss: 9.1762
# Epoch  66/75 | TF=ON | Training loss: 8.0414
# Epoch  67/75 | TF=ON | Training loss: 7.6352
# Epoch  68/75 | TF=ON | Training loss: 7.4190
# Epoch  69/75 | TF=OFF | Training loss: 16.0154
# Epoch  70/75 | TF=OFF | Training loss: 14.2941
# Epoch  71/75 | TF=OFF | Training loss: 13.8705
# Epoch  72/75 | TF=OFF | Training loss: 13.6827
# Epoch  73/75 | TF=ON | Training loss: 9.0172
# Epoch  74/75 | TF=ON | Training loss: 7.8722
# Epoch  75/75 | TF=ON | Training loss: 7.5011
#    💾 Checkpoint saved at epoch 75
#
# 🏋️ Training Completed
#
# Total time: 03:04:31
# Model saved to: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_class_26.03.19.18.38
# ======================================================================

# %%
from training.loop import train_model

dataset_path      = "../data/trumpet1/"      # Path to dataset directory
output_model_path = "output_Film_"+timestamp # Path to save the trained model and configs
results = train_model(
    dataset_path      = dataset_path,
    model_output_path = output_model_path,
    num_epochs        = 75,      # Number of epochs. 75 works well for most training sessions.
    batch_size        = 100,    # Number of sequences per batch.
    sequence_length   = 125,    # Number of tokens per training sequence.
    batches_per_epoch = 100,    # Number of batches per epoch.
    learning_rate     = 0.005,  # Adam optimizer learning rate.
    hidden_size       = 128,    # GRU hidden state size.
    num_layers        = 3,      # Number of GRU layers in the model.
    save_interval     = 25,     # Save model every N epochs (last checkpoint is always saved).
    add_noise         = True,   # Whether to add noise to embeddings during training.
    noise_weight      = 0.05,   # Weight of noise added to embeddings during training for stability.
    cascade_mode      = "hard", # Codebook learning mode: "hard" or "soft". If "hard", probabilities are used to sample the codebook token. If "soft", probabilities are used as weights for the loss of each codebook.
    conditioning_mode= "film", # Input conditioning path ("concat", "film")
    temperature       = 0.8,    # Controls randomness when sampling (only for cascade_mode="hard".)
    top_n             = 8,      # Sample from top_n tokens only (only for cascade_mode="hard".)
    tau_soft          = 0.6,    # Soft cascade temperature (only for cascade_mode="soft".)
    train_splits      = ["train"],      # Training split(s) - None for auto-detect, or "train" or ["train", "extra"].
    # val_splits        = ["validation"], # Validation split(s) - None for auto-detect, or "validation" or ["val1", "val2"].
    TF_schedule       = [4, 4], # Teacher forcing cicle [epochs_on, epochs_off]. Always starts with "on".
    simulate_parallel = False,  # If True, all codebook are learned in parallel (no cascade.)
    use_tensorboard   = True,   # If True, log to TensorBoard.
    use_tqdm          = True,   # If True, show progress bars per epoch.
    val_interval      = 2,      # Run validation every N epochs.
    quantizer_weights = [3.0, 2.0, 1.5, 1.0, 0.8, 0.6, 0.5, 0.4] # Per-codebook loss weights.
)
# Out:
# 🚀 Training Configurations
#
# 💻 Device: cpu
# 📋 Conditioning configuration:
#     Features: pitch
#     Total features: 1
#     FPS: 75
# 📊 Available splits: train
# 📦 Creating data loaders...
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Latents embedded in 128 of the GRU input size of 128
# FiLM conditioning enabled on GRU input
# 🧠 Model created:
#     Device: cpu
#     Conditioning features: 1
#     Hidden size: 128
#     Layers: 3
#     Codebooks: 8
#     Conditioning mode: film
#     Cascade mode: hard
#     Temperature: 0.8
#     Top-k: 8
# 📋 Copied conditioning_config.json to model directory
# saved to /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_Film_26.03.19.18.38/config_v2.pt
# wrote json param file
# 💾 Saved conditioning config to: conditioning_config.pt
# 💾 Output directory: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_Film_26.03.19.18.38
# 💾 Saved configuration to: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_Film_26.03.19.18.38/config_v2.pt
#
# 🏋️ Training Started
#
# Epochs: 1 → 75
# Batches per epoch: 100
# Batch size: 100
# TF schedule: [4, 4]
# Simulate parallel: False
# Validation: Disabled
# Tensorboard: Enabled
#     run in a new terminal: tensorboard --logdir=/Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_Film_26.03.19.18.38/tensorboard
# ======================================================================
# Epoch   1/75 | TF=ON | Training loss: 34.7687
# Epoch   2/75 | TF=ON | Training loss: 28.0693
# Epoch   3/75 | TF=ON | Training loss: 26.4201
# Epoch   4/75 | TF=ON | Training loss: 24.4524
# Epoch   5/75 | TF=OFF | Training loss: 43.0173
# Epoch   6/75 | TF=OFF | Training loss: 35.2401
# Epoch   7/75 | TF=OFF | Training loss: 32.1600
# Epoch   8/75 | TF=OFF | Training loss: 29.9014
# Epoch   9/75 | TF=ON | Training loss: 20.8364
# Epoch  10/75 | TF=ON | Training loss: 18.2338
# Epoch  11/75 | TF=ON | Training loss: 15.7961
# Epoch  12/75 | TF=ON | Training loss: 14.7079
# Epoch  13/75 | TF=OFF | Training loss: 26.4111
# Epoch  14/75 | TF=OFF | Training loss: 22.6436
# Epoch  15/75 | TF=OFF | Training loss: 21.4250
# Epoch  16/75 | TF=OFF | Training loss: 20.6780
# Epoch  17/75 | TF=ON | Training loss: 15.1869
# Epoch  18/75 | TF=ON | Training loss: 13.0845
# Epoch  19/75 | TF=ON | Training loss: 12.2434
# Epoch  20/75 | TF=ON | Training loss: 11.7203
# Epoch  21/75 | TF=OFF | Training loss: 22.4511
# Epoch  22/75 | TF=OFF | Training loss: 19.7100
# Epoch  23/75 | TF=OFF | Training loss: 19.0118
# Epoch  24/75 | TF=OFF | Training loss: 18.6023
# Epoch  25/75 | TF=ON | Training loss: 13.4027
#    💾 Checkpoint saved at epoch 25
# Epoch  26/75 | TF=ON | Training loss: 11.6133
# Epoch  27/75 | TF=ON | Training loss: 10.9908
# Epoch  28/75 | TF=ON | Training loss: 10.6059
# Epoch  29/75 | TF=OFF | Training loss: 21.1491
# Epoch  30/75 | TF=OFF | Training loss: 18.6058
# Epoch  31/75 | TF=OFF | Training loss: 18.0187
# Epoch  32/75 | TF=OFF | Training loss: 17.6844
# Epoch  33/75 | TF=ON | Training loss: 12.5230
# Epoch  34/75 | TF=ON | Training loss: 10.8613
# Epoch  35/75 | TF=ON | Training loss: 10.2918
# Epoch  36/75 | TF=ON | Training loss: 9.9617
# Epoch  37/75 | TF=OFF | Training loss: 20.3807
# Epoch  38/75 | TF=OFF | Training loss: 17.9368
# Epoch  39/75 | TF=OFF | Training loss: 17.3731
# Epoch  40/75 | TF=OFF | Training loss: 18.9447
# Epoch  41/75 | TF=ON | Training loss: 12.1807
# Epoch  42/75 | TF=ON | Training loss: 10.5448
# Epoch  43/75 | TF=ON | Training loss: 9.9771
# Epoch  44/75 | TF=ON | Training loss: 9.6463
# Epoch  45/75 | TF=OFF | Training loss: 19.8679
# Epoch  46/75 | TF=OFF | Training loss: 17.5191
# Epoch  47/75 | TF=OFF | Training loss: 16.9888
# Epoch  48/75 | TF=OFF | Training loss: 16.6792
# Epoch  49/75 | TF=ON | Training loss: 11.5656
# Epoch  50/75 | TF=ON | Training loss: 10.0356
#    💾 Checkpoint saved at epoch 50
# Epoch  51/75 | TF=ON | Training loss: 9.5353
# Epoch  52/75 | TF=ON | Training loss: 9.2330
# Epoch  53/75 | TF=OFF | Training loss: 19.4152
# Epoch  54/75 | TF=OFF | Training loss: 17.1278
# Epoch  55/75 | TF=OFF | Training loss: 16.5709
# Epoch  56/75 | TF=OFF | Training loss: 16.3097
# Epoch  57/75 | TF=ON | Training loss: 11.1937
# Epoch  58/75 | TF=ON | Training loss: 9.7224
# Epoch  59/75 | TF=ON | Training loss: 9.2502
# Epoch  60/75 | TF=ON | Training loss: 8.9753
# Epoch  61/75 | TF=OFF | Training loss: 19.0659
# Epoch  62/75 | TF=OFF | Training loss: 16.7724
# Epoch  63/75 | TF=OFF | Training loss: 16.2971
# Epoch  64/75 | TF=OFF | Training loss: 16.0494
# Epoch  65/75 | TF=ON | Training loss: 10.9247
# Epoch  66/75 | TF=ON | Training loss: 9.5014
# Epoch  67/75 | TF=ON | Training loss: 9.0395
# Epoch  68/75 | TF=ON | Training loss: 8.7627
# Epoch  69/75 | TF=OFF | Training loss: 18.7712
# Epoch  70/75 | TF=OFF | Training loss: 16.5559
# Epoch  71/75 | TF=OFF | Training loss: 16.0164
# Epoch  72/75 | TF=OFF | Training loss: 15.8335
# Epoch  73/75 | TF=ON | Training loss: 10.7355
# Epoch  74/75 | TF=ON | Training loss: 9.3235
# Epoch  75/75 | TF=ON | Training loss: 8.8603
#    💾 Checkpoint saved at epoch 75
#
# 🏋️ Training Completed
#
# Total time: 03:04:02
# Model saved to: /Users/oriolfreixa/Documents/GitHub/GenAI/rnencodec-onehot/quickstart/output_Film_26.03.19.18.38
# ======================================================================
