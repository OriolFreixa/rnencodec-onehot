# %%
# Make repo root importable for this session (zero packaging)
import sys, pathlib
repo_root = pathlib.Path.cwd().parent if (pathlib.Path.cwd().name == "quickstart") else pathlib.Path.cwd()
sys.path.insert(0, str(repo_root))
# %load_ext autoreload
# %autoreload 2

model_path      = "output_class_26.03.12.11.16" # Path to save the trained model and configs
checkpoint_name = "last_checkpoint.pt"   # Checkpoint to use for inference (e.g., "last_checkpoint.pt" or "checkpoint_75.pt")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from inference.rt import run_inference

# Hard cascade inference
run_inference(
    model_dir=model_path,
    checkpoint_name=checkpoint_name,
    cascade_mode="hard" # It can also be "soft"
)
# Out:
# Loaded conditioning config with 12 features:
#   - class_C: binary
#   - class_C#: binary
#   - class_D: binary
#   - class_D#: binary
#   - class_E: binary
#   - class_F: binary
#   - class_F#: binary
#   - class_G: binary
#   - class_G#: binary
#   - class_A: binary
#   - class_A#: binary
#   - class_B: binary
#
# Loading EnCodec model...
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Using checkpoint: last_checkpoint.pt
# ⚠️  Overriding cascade mode: hard → hard
# ⚠️  Overriding temperature: 0.8
# ⚠️  Overriding top-k: 8
# Loading RNN model from last_checkpoint.pt...
# Initializing the RNNGeneratorSoft on device = cpu
# Latents embedded in 64 of the GRU input size of 128
# Conditioning parameters embedded in 64 of the GRU input size of 128
# Model loaded successfully!
#   - Hidden size: 128
#   - Num layers: 3
#   - Conditioning size: 12
#   - Cascade mode: hard
#   - Hard sampling mode: sample
#   - Temperature: 0.8
#   - Top-k: 8
#   - Device: cpu
#
# Initializing real-time synthesizer...
# Parameter configuration:
#   - class_C: 0.50 probability (range: 0.0-1.0 probability)
#   - class_C#: 0.50 probability (range: 0.0-1.0 probability)
#   - class_D: 0.50 probability (range: 0.0-1.0 probability)
#   - class_D#: 0.50 probability (range: 0.0-1.0 probability)
#   - class_E: 0.50 probability (range: 0.0-1.0 probability)
#   - class_F: 0.50 probability (range: 0.0-1.0 probability)
#   - class_F#: 0.50 probability (range: 0.0-1.0 probability)
#   - class_G: 0.50 probability (range: 0.0-1.0 probability)
#   - class_G#: 0.50 probability (range: 0.0-1.0 probability)
#   - class_A: 0.50 probability (range: 0.0-1.0 probability)
#   - class_A#: 0.50 probability (range: 0.0-1.0 probability)
#   - class_B: 0.50 probability (range: 0.0-1.0 probability)
# Initialize EncodecRTPlayer
# VBox(children=(HBox(children=(VBox(children=(FloatSlider(value=0.5, description='class_C', layout=Layout(width…
# HTML(value='')
# ✓ Real-time synthesizer ready!
#   Use the GUI to control parameters and generate audio in real-time.
#   Note: Check synth.gen._last_error after stopping to see any runtime issues.
# (<realtime_synth.engine.RealtimeSynth at 0x167eef530>,
#  VBox(children=(HBox(children=(VBox(children=(FloatSlider(value=0.5, description='class_C', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001), FloatSlider(value=0.5, description='class_C#', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001), FloatSlider(value=0.5, description='class_D', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001), FloatSlider(value=0.5, description='class_D#', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001), FloatSlider(value=0.5, description='class_E', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001), FloatSlider(value=0.5, description='class_F', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001), FloatSlider(value=0.5, description='class_F#', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001), FloatSlider(value=0.5, description='class_G', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001), FloatSlider(value=0.5, description='class_G#', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001), FloatSlider(value=0.5, description='class_A', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001), FloatSlider(value=0.5, description='class_A#', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001), FloatSlider(value=0.5, description='class_B', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001))), VBox(children=(Label(value='class_C: 0.50 probability', layout=Layout(width='300px')), Label(value='class_C#: 0.50 probability', layout=Layout(width='300px')), Label(value='class_D: 0.50 probability', layout=Layout(width='300px')), Label(value='class_D#: 0.50 probability', layout=Layout(width='300px')), Label(value='class_E: 0.50 probability', layout=Layout(width='300px')), Label(value='class_F: 0.50 probability', layout=Layout(width='300px')), Label(value='class_F#: 0.50 probability', layout=Layout(width='300px')), Label(value='class_G: 0.50 probability', layout=Layout(width='300px')), Label(value='class_G#: 0.50 probability', layout=Layout(width='300px')), Label(value='class_A: 0.50 probability', layout=Layout(width='300px')), Label(value='class_A#: 0.50 probability', layout=Layout(width='300px')), Label(value='class_B: 0.50 probability', layout=Layout(width='300px')))))), HBox(children=(ToggleButton(value=False, description='▶️ Play', layout=Layout(width='150px')),)), HTML(value='<small>Adjust parameters in real-time. Values update as you move the sliders.<br>Tip: decrease blocksize for lower latency (higher xrun risk); increase if you hear clicks.</small>'))))

# %%
model_path      = "output_26.02.28.18.08" # Path to save the trained model and configs
checkpoint_name = "last_checkpoint.pt"   # Checkpoint to use for inference (e.g., "last_checkpoint.pt" or "checkpoint_75.pt")

# Hard cascade inference
run_inference(
    model_dir=model_path,
    checkpoint_name=checkpoint_name,
    cascade_mode="hard" # It can also be "soft"
)
# Out:
# Loaded conditioning config with 1 features:
#   - pitch: 230-450 Hz
#
# Loading EnCodec model...
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Using checkpoint: last_checkpoint.pt
# ⚠️  Overriding cascade mode: hard → hard
# ⚠️  Overriding temperature: 0.8
# ⚠️  Overriding top-k: 8
# Loading RNN model from last_checkpoint.pt...
# Initializing the RNNGeneratorSoft on device = cpu
# Latents embedded in 64 of the GRU input size of 128
# Conditioning parameters embedded in 64 of the GRU input size of 128
# Model loaded successfully!
#   - Hidden size: 128
#   - Num layers: 3
#   - Conditioning size: 1
#   - Cascade mode: hard
#   - Hard sampling mode: sample
#   - Temperature: 0.8
#   - Top-k: 8
#   - Device: cpu
#
# Initializing real-time synthesizer...
# Parameter configuration:
#   - pitch: 340.00 Hz (range: 230.0-450.0 Hz)
# Initialize EncodecRTPlayer
# VBox(children=(HBox(children=(VBox(children=(FloatSlider(value=0.5, description='pitch', layout=Layout(width='…
# HTML(value='')
# ✓ Real-time synthesizer ready!
#   Use the GUI to control parameters and generate audio in real-time.
#   Note: Check synth.gen._last_error after stopping to see any runtime issues.
# (<realtime_synth.engine.RealtimeSynth at 0x168f3a060>,
#  VBox(children=(HBox(children=(VBox(children=(FloatSlider(value=0.5, description='pitch', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001),)), VBox(children=(Label(value='pitch: 340.00 Hz', layout=Layout(width='300px')),)))), HBox(children=(ToggleButton(value=False, description='▶️ Play', layout=Layout(width='150px')),)), HTML(value='<small>Adjust parameters in real-time. Values update as you move the sliders.<br>Tip: decrease blocksize for lower latency (higher xrun risk); increase if you hear clicks.</small>'))))

# %%
model_path      = "output_Film_26.03.12.11.16" # Path to save the trained model and configs
checkpoint_name = "last_checkpoint.pt"   # Checkpoint to use for inference (e.g., "last_checkpoint.pt" or "checkpoint_75.pt")

# Hard cascade inference
run_inference(
    model_dir=model_path,
    checkpoint_name=checkpoint_name,
    cascade_mode="hard" # It can also be "soft"
)
# Out:
# Loaded conditioning config with 1 features:
#   - pitch: 230-450 Hz
#
# Loading EnCodec model...
# Loading weights:   0%|          | 0/252 [00:00<?, ?it/s]
# Using checkpoint: last_checkpoint.pt
# ⚠️  Overriding cascade mode: hard → hard
# ⚠️  Overriding temperature: 0.8
# ⚠️  Overriding top-k: 8
# Loading RNN model from last_checkpoint.pt...
# Initializing the RNNGeneratorSoft on device = cpu
# Latents embedded in 128 of the GRU input size of 128
# FiLM conditioning enabled on GRU input
# Model loaded successfully!
#   - Hidden size: 128
#   - Num layers: 3
#   - Conditioning size: 1
#   - Cascade mode: hard
#   - Hard sampling mode: sample
#   - Temperature: 0.8
#   - Top-k: 8
#   - Device: cpu
#
# Initializing real-time synthesizer...
# Parameter configuration:
#   - pitch: 340.00 Hz (range: 230.0-450.0 Hz)
# Initialize EncodecRTPlayer
# VBox(children=(HBox(children=(VBox(children=(FloatSlider(value=0.5, description='pitch', layout=Layout(width='…
# HTML(value='')
# ✓ Real-time synthesizer ready!
#   Use the GUI to control parameters and generate audio in real-time.
#   Note: Check synth.gen._last_error after stopping to see any runtime issues.
# (<realtime_synth.engine.RealtimeSynth at 0x167e19ca0>,
#  VBox(children=(HBox(children=(VBox(children=(FloatSlider(value=0.5, description='pitch', layout=Layout(width='500px'), max=1.0, readout=False, step=0.001),)), VBox(children=(Label(value='pitch: 340.00 Hz', layout=Layout(width='300px')),)))), HBox(children=(ToggleButton(value=False, description='▶️ Play', layout=Layout(width='150px')),)), HTML(value='<small>Adjust parameters in real-time. Values update as you move the sliders.<br>Tip: decrease blocksize for lower latency (higher xrun risk); increase if you hear clicks.</small>'))))
